# %%
from linear_regression_gd import LinearRegression
from linear_regression_ols import LinearRegressionOLS
# Out:
# MSE: 0.2373188146679574
# R2 Score: 0.7402063997736819
# OLS Results
# MSE: 0.24103224266549816
# R2 Score: 0.736141299288446
